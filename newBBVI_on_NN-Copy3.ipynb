# %% [markdown]
# ### IMPORTS

# %%
from Inference.Variational import MeanFieldVariationalDistribution

# %%
import torch
from torch import nn
from torch import functional as F
import matplotlib.pyplot as plt
import numpy as np
from livelossplot import PlotLosses
from Tools.NNtools import *

# %%
# Find what device to work with
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cpu')

# %%
def gaussian_entropy(sigma):
    return 0.5 * q.sigma.shape[0] * (1.0 + torch.log(2*torch.tensor(np.pi))) + torch.sum(torch.log(sigma))

# %%
def _log_norm(x, mu, std):
        return -0.5 * torch.log(2*np.pi*std**2) -(0.5 * (1/(std**2))* (x-mu)**2)

# %%
# load data and make it in proper shape
data = torch.load('data/foong_data.pt')
x_data = data[0].to(device)
y_data = data[1].to(device)
y_data = y_data.unsqueeze(-1)

# %%
# load data and make it in proper shape
data_val = torch.load('data/foong_data_validation.pt')
x_data_val = data_val[0].to(device)
y_data_val = data_val[1].to(device)
y_data_val = y_data_val.unsqueeze(-1)

# %%
model = nn.Sequential( nn.Linear(1, 1),
                      nn.Tanh()
                     ).to(device)

# %%
param_count = get_param(model).shape[0]

# %%
prior = MeanFieldVariationalDistribution(param_count, sigma=1.0, device=device)
prior.mu.requires_grad = False
prior.rho.requires_grad = False

# %%
def logprior(x):
    return prior.log_prob(x)

# %%
sigma_like=.1

def loglikelihood(theta, model, x, y, sigma_likeli=sigma_like):
    #set_param(model, theta)
    set_all_parameters(model, theta)
    y_pred = model(x)
    L = _log_norm(y_pred, y, torch.tensor([sigma_likeli],device=device))
    return torch.sum(L).unsqueeze(-1)

# %%
def logposterior(theta, model, x, y, sigma_likeli=sigma_like):
    return logprior(theta) + loglikelihood(theta, model, x, y, sigma_likeli)

# %%
param_count
# Out:
# 2

# %%
q = MeanFieldVariationalDistribution(param_count, sigma=1.0, device=device)
q.mu = nn.Parameter(prior.sample()[0,:].detach().clone().to(device), requires_grad=True) 

q.rho.requires_grad = True
q.mu.requires_grad = True

# %%
def flip_parameters_to_tensors(module):
    attr = []
    while bool(module._parameters):
        attr.append( module._parameters.popitem() )
    setattr(module, 'registered_parameters_name', [])

    for i in attr:
        setattr(module, i[0], torch.zeros(i[1].shape,requires_grad=True))
        module.registered_parameters_name.append(i[0])

    module_name = [k for k,v in module._modules.items()]

    for name in module_name:
        flip_parameters_to_tensors(module._modules[name])

# %%
def set_all_parameters(module, theta):
    count = 0  

    for name in module.registered_parameters_name:
        a = count
        b = a + getattr(module, name).numel()
        t = torch.reshape(theta[0,a:b], getattr(module, name).shape)
        setattr(module, name, t)

        count += getattr(module, name).numel()

    module_name = [k for k,v in module._modules.items()]
    for name in module_name:
        count += set_all_parameters(module._modules[name], theta)
    return count

# %%
flip_parameters_to_tensors(model)

# %%
n_samples_ELBO = 10

# %%
optimizer = torch.optim.Adam(q.parameters(), lr=0.1)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, patience=50, factor=0.5)

# %%
q.mu.detach_().requires_grad_(True)
q.rho.detach_().requires_grad_(True)
# Out:
# Parameter containing:
# tensor([-3.7661, -3.8462], requires_grad=True)

# %%
liveloss = PlotLosses()
for t in range(10000):
    logs = {}
    optimizer.zero_grad()

    listDIV = []
    for i in range(n_samples_ELBO):
        z = q.sample(1)
        LQ = q.log_prob(z)
        LP = logposterior(z, model, x_data, y_data)
        listDIV.append((LQ - LP))

    L = torch.stack(listDIV).mean()

    #with torch.no_grad():
    #    LL = predictive_loglikelihood(z).mean().detach().clone()

    L.backward()

    learning_rate = optimizer.param_groups[0]['lr']

    scheduler.step(L.detach().clone().cpu().numpy())
    logs['ELBO'] = L.detach().clone().cpu().numpy()
    logs['learning rate'] = learning_rate
    #logs['memory'] = torch.cuda.memory_allocated(device=device)
    #logs['predictive likelihood'] = LL.detach().clone().cpu().numpy()
    liveloss.update(logs)

    if t % 10 == 0:
        liveloss.draw()

    optimizer.step()

    if learning_rate < 0.00001:
        break
# Out:
# <div id='cbd88945-77f5-40e4-901f-038ffa763e21'></div>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-50-e993bc97c9a6> in <module>
#      28
#      29     if t % 10 == 0:
# ---> 30         liveloss.draw()
#      31
#      32     optimizer.step()
#
# /opt/anaconda3/lib/python3.7/site-packages/livelossplot/generic_plot.py in draw(self)
#     114                       skip_first=self.skip_first,
#     115                       extra_plots=self.extra_plots,
# --> 116                       fig_path=self.fig_path)
#     117             if self.metrics_extrema:
#     118                 print_extrema(self.logs,
#
# /opt/anaconda3/lib/python3.7/site-packages/livelossplot/core.py in draw_plot(logs, metrics, figsize, max_epoch, max_cols, series_fmt, metric2title, skip_first, extra_plots, fig_path)
#      66         extra_plot(logs)
#      67
# ---> 68     plt.tight_layout()
#      69     if fig_path is not None:
#      70         plt.savefig(fig_path)
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in tight_layout(pad, h_pad, w_pad, rect)
#    1373         labels) will fit into. Default is (0, 0, 1, 1).
#    1374     """
# -> 1375     gcf().tight_layout(pad=pad, h_pad=h_pad, w_pad=w_pad, rect=rect)
#    1376
#    1377
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/figure.py in tight_layout(self, renderer, pad, h_pad, w_pad, rect)
#    2474         kwargs = get_tight_layout_figure(
#    2475             self, self.axes, subplotspec_list, renderer,
# -> 2476             pad=pad, h_pad=h_pad, w_pad=w_pad, rect=rect)
#    2477         if kwargs:
#    2478             self.subplots_adjust(**kwargs)
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/tight_layout.py in get_tight_layout_figure(fig, axes_list, subplotspec_list, renderer, pad, h_pad, w_pad, rect)
#     360                                      subplot_list=subplot_list,
#     361                                      ax_bbox_list=ax_bbox_list,
# --> 362                                      pad=pad, h_pad=h_pad, w_pad=w_pad)
#     363
#     364     # kwargs can be none if tight_layout fails...
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/tight_layout.py in auto_adjust_subplotpars(fig, renderer, nrows_ncols, num1num2_list, subplot_list, ax_bbox_list, pad, h_pad, w_pad, rect)
#     109             continue
#     110
# --> 111         tight_bbox_raw = union([ax.get_tightbbox(renderer) for ax in subplots
#     112                                 if ax.get_visible()])
#     113         tight_bbox = TransformedBbox(tight_bbox_raw,
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/tight_layout.py in <listcomp>(.0)
#     110
#     111         tight_bbox_raw = union([ax.get_tightbbox(renderer) for ax in subplots
# --> 112                                 if ax.get_visible()])
#     113         tight_bbox = TransformedBbox(tight_bbox_raw,
#     114                                      fig.transFigure.inverted())
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py in get_tightbbox(self, renderer, call_axes_locator, bbox_extra_artists)
#    4391                     # this artist
#    4392                     continue
# -> 4393             bbox = a.get_tightbbox(renderer)
#    4394             if (bbox is not None
#    4395                     and 0 < bbox.width < np.inf
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/artist.py in get_tightbbox(self, renderer)
#     282             The enclosing bounding box (in figure pixel co-ordinates).
#     283         """
# --> 284         bbox = self.get_window_extent(renderer)
#     285         if self.get_clip_on():
#     286             clip_box = self.get_clip_box()
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/spines.py in get_window_extent(self, renderer)
#     201             bboxes.append(bb0)
#     202
# --> 203         return mtransforms.Bbox.union(bboxes)
#     204
#     205     def get_path(self):
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/transforms.py in union(bboxes)
#     703         x1 = np.max([bbox.xmax for bbox in bboxes])
#     704         y0 = np.min([bbox.ymin for bbox in bboxes])
# --> 705         y1 = np.max([bbox.ymax for bbox in bboxes])
#     706         return Bbox([[x0, y0], [x1, y1]])
#     707
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/transforms.py in <listcomp>(.0)
#     703         x1 = np.max([bbox.xmax for bbox in bboxes])
#     704         y0 = np.min([bbox.ymin for bbox in bboxes])
# --> 705         y1 = np.max([bbox.ymax for bbox in bboxes])
#     706         return Bbox([[x0, y0], [x1, y1]])
#     707
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/transforms.py in ymax(self)
#     363     def ymax(self):
#     364         """The top edge of the bounding box."""
# --> 365         return np.max(self.get_points()[:, 1])
#     366
#     367     @property
#
# <__array_function__ internals> in amax(*args, **kwargs)
#
# /opt/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py in amax(a, axis, out, keepdims, initial, where)
#    2619     """
#    2620     return _wrapreduction(a, np.maximum, 'max', axis, None, out,
# -> 2621                           keepdims=keepdims, initial=initial, where=where)
#    2622
#    2623
#
# /opt/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      71
#      72
# ---> 73 def _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs):
#      74     passkwargs = {k: v for k, v in kwargs.items()
#      75                   if v is not np._NoValue}
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt

# %%
LQ = []
LP = []

Z = []
for i in range(5000):
    z = q.sample(1)
    Z.append(z.detach().clone().cpu())
    LQ.append(q.log_prob(z).squeeze().squeeze().detach().clone().cpu().numpy())
    LP.append(logposterior(z, model, x_data, y_data, sigma_noise=0.1).squeeze().squeeze().detach().clone().cpu().numpy())

# %%
np.mean(np.stack(LQ) - 150 > np.stack(LP))

# %%
np.max(np.stack(LP) - np.stack(LQ))

# %%
np.max(np.exp(np.stack(LP) - np.stack(LQ) + 150))

# %%
plt.hist(np.stack(LP),bins=100);

# %%
plt.hist(np.stack(LQ),bins=100);

# %%
plt.hist(np.stack(LP),bins=100);

# %%
lw = torch.tensor(np.stack(LP) - np.stack(LQ))

# %%
plt.plot(torch.exp(lw).cpu().numpy())

# %%
(q.mu,q.sigma)

# %%
R=100
side_0 = np.linspace(-100,100.,R)
side_1 = np.linspace(-100,100.,R)
a_,b_ = np.meshgrid(side_0,side_1)

D = np.zeros(a_.shape)
#Q = np.zeros(a_.shape)
for i in range(R):
    for j in range(R):
        dd=loglikelihood(torch.Tensor([[a_[i,j],b_[i,j]]]), model, x_data, y_data)
        #qq=q.log_prob(torch.Tensor([[a_[i,j],b_[i,j]]])).exp()#
        D[i,j]=dd.squeeze().squeeze().detach().clone().cpu().numpy()
 #       Q[i,j]=qq.squeeze().squeeze().detach().clone().cpu().numpy()

# %%
# %matplotlib notebook
plt.pcolormesh(a_,b_,D)
#mu=q.mu.squeeze().detach().clone().cpu().numpy()
#plt.scatter(mu[0],mu[1],c='r')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.hist(np.stack(LQ),bins=100);

# %%
m = torch.distributions.Categorical(torch.exp(lw - torch.logsumexp(lw, dim=0)))

# %%
m.sample()

# %%
P = torch.exp(lw - torch.logsumexp(lw, dim=0)).sort()

# %%
P[0][-10:-1]

# %%
# Sampling the distribution over Neural Networks 1000 times, and plotting with transparency to make it appear as a smooth distribution
fig, ax = plt.subplots()
fig.set_size_inches(11.7, 8.27)
plt.xlim(-2, 2) 
plt.ylim(-4, 4) 
plt.scatter(x_data.cpu(), y_data.cpu())
for _ in range(1000):
    z = q.sample().to(device)
    set_all_parameters(model, z)
    y_test = model(x_test)

    plt.plot(x_test.detach().cpu().numpy(), y_test.squeeze(0).detach().cpu().numpy(), alpha=0.05, linewidth=1, color='lightblue')

# %%
x_test = torch.linspace(-2.0, 2.0).unsqueeze(1).to(device)

# %%
# Sampling the distribution over Neural Networks 1000 times, and plotting with transparency to make it appear as a smooth distribution
fig, ax = plt.subplots()
fig.set_size_inches(11.7, 8.27)
plt.xlim(-2, 2) 
plt.ylim(-4, 4) 
plt.scatter(x_data.cpu(), y_data.cpu())
for _ in range(1000):
    z = q.sample()
    set_all_parameters(model, z)
    y_test = model(x_test)

    plt.plot(x_test.detach().cpu().numpy(), y_test.squeeze(0).detach().cpu().numpy(), alpha=0.05, linewidth=1, color='lightblue')

# %%
# Sampling the distribution over Neural Networks 1000 times, and plotting with transparency to make it appear as a smooth distribution
fig, ax = plt.subplots()
fig.set_size_inches(11.7, 8.27)
plt.scatter(x_data.cpu(), y_data.cpu())
for _ in range(1000):
    z = prior.sample()
    set_all_parameters(model, z)
    y_test = model(x_test)

    plt.plot(x_test.detach().cpu().numpy(), y_test.squeeze(0).detach().cpu().numpy(), alpha=0.05, linewidth=1, color='lightblue')
