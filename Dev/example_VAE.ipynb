# %%
import numpy as np
import math
import torch
from torch import nn
from torch import functional as F
import scipy.stats as stats
import matplotlib
import matplotlib.pyplot as plt
from livelossplot import PlotLosses
from Inference.Variational import MeanFieldVariationalDistribution
from Inference.VariationalAE import MeanFieldVariationalAE
from Tools.NNtools import *

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cpu')

# %% [markdown]
# # Target density #

# %%
target_component = [torch.distributions.normal.Normal(-1.0, 0.2),
           torch.distributions.normal.Normal(1.0, 0.2)]
     #      torch.distributions.normal.Normal(-5.0, 0.2)]
target_proportions = torch.tensor([0.5, 0.5,
                                  ])#0.20])

# %%
def target(x):
    return torch.exp(logtarget(x))

def logtarget(x):
    logp = [None]*len(target_component)
    for j in range(len(target_component)):
        logp[j] = target_component[j].log_prob(x) + target_proportions[j].log()
    return torch.logsumexp(torch.cat(logp,dim=1),dim=1).unsqueeze(-1)

# %%
# %matplotlib notebook
# %matplotlib notebook

x_lin = torch.arange(-10, 10.0, 0.01).unsqueeze(-1)
Z = (1/(torch.sum(target(x_lin),dim=0)*0.01)).detach().cpu().numpy()
plt.plot(x_lin.detach().cpu().numpy(), Z*target(x_lin).detach().cpu().numpy())
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # AE-Variational Distribution #

# %%
nb_latent=10
VAE = MeanFieldVariationalAE(nb_latent,10,3,nn.Tanh())
VAE_param_count = get_param(VAE).shape[0]
VAE_param_count
# Out:
# 163

# %%
def init_weights(m):
    if type(m) == nn.Linear:
        torch.nn.init.xavier_uniform_(m.weight)
        m.bias.data.fill_(0.01)
VAE.decoder.apply(init_weights)
# Out:
# Sequential(
#   (0): Linear(in_features=10, out_features=10, bias=True)
#   (1): Tanh()
#   (2): Linear(in_features=10, out_features=3, bias=True)
# )

# %%
def KLDivGauss(mu,sigma):
    Div=sigma+mu**2-sigma.log()-1
    return 0.5*Div.sum().squeeze()

# %%
n_samples_VAR = 100

# %%
optimizer = torch.optim.Adam(VAE.parameters(), lr=0.1)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, patience=30, factor=0.5)

# %%
# %matplotlib inline
liveloss = PlotLosses()
for t in range(10000):
    logs = {}
    optimizer.zero_grad()

    
    Div = KLDivGauss(VAE.mfvar.mu,VAE.mfvar.sigma)
    
    LL=torch.Tensor(n_samples_VAR)
    for i in range(n_samples_VAR):
        theta = VAE()
        LL[i]=logtarget(theta)
    L = Div - LL.mean()

    L.backward()
    
    learning_rate = optimizer.param_groups[0]['lr']
    
    scheduler.step(L.detach().clone().cpu().numpy())
    logs['ELBO'] = L.detach().clone().cpu().numpy()
    logs['learning rate'] = learning_rate
    liveloss.update(logs)
    
    if t % 10 == 0:
        liveloss.draw()

    optimizer.step()
    
    if learning_rate < 0.00001:
        break
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-da1f616943b3> in <module>
#      24
#      25     if t % 10 == 0:
# ---> 26         liveloss.draw()
#      27
#      28     optimizer.step()
#
# ~\Anaconda3\envs\MachineLearningV1\lib\site-packages\livelossplot\generic_plot.py in draw(self)
#     114                       skip_first=self.skip_first,
#     115                       extra_plots=self.extra_plots,
# --> 116                       fig_path=self.fig_path)
#     117             if self.metrics_extrema:
#     118                 print_extrema(self.logs,
#
# ~\Anaconda3\envs\MachineLearningV1\lib\site-packages\livelossplot\core.py in draw_plot(logs, metrics, figsize, max_epoch, max_cols, series_fmt, metric2title, skip_first, extra_plots, fig_path)
#      40
#      41     for metric_id, metric in enumerate(metrics):
# ---> 42         plt.subplot(max_rows, max_cols, metric_id + 1)
#      43
#      44         if max_epoch is not None:
#
# ~\Anaconda3\envs\MachineLearningV1\lib\site-packages\matplotlib\pyplot.py in subplot(*args, **kwargs)
#    1074
#    1075     fig = gcf()
# -> 1076     a = fig.add_subplot(*args, **kwargs)
#    1077     bbox = a.bbox
#    1078     byebye = []
#
# ~\Anaconda3\envs\MachineLearningV1\lib\site-packages\matplotlib\figure.py in add_subplot(self, *args, **kwargs)
#    1412                     self._axstack.remove(ax)
#    1413
# -> 1414             a = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1415
#    1416         return self._add_axes_internal(key, a)
#
# ~\Anaconda3\envs\MachineLearningV1\lib\site-packages\matplotlib\axes\_subplots.py in __init__(self, fig, *args, **kwargs)
#      67
#      68         # _axes_class is set in the subplot_class_factory
# ---> 69         self._axes_class.__init__(self, fig, self.figbox, **kwargs)
#      70         # add a layout box to this, for both the full axis, and the poss
#      71         # of the axis.  We need both because the axes may become smaller
#
# ~\Anaconda3\envs\MachineLearningV1\lib\site-packages\matplotlib\axes\_base.py in __init__(self, fig, rect, facecolor, frameon, sharex, sharey, label, xscale, yscale, **kwargs)
#     493         self._rasterization_zorder = None
#     494         self._connected = {}  # a dict from events to (id, func)
# --> 495         self.cla()
#     496
#     497         # funcs used to format x and y - fall back on major formatters
#
# ~\Anaconda3\envs\MachineLearningV1\lib\site-packages\matplotlib\axes\_base.py in cla(self)
#    1043         self.containers = []
#    1044
# -> 1045         self.grid(False)  # Disable grid on init to use rcParameter
#    1046         self.grid(self._gridOn, which=rcParams['axes.grid.which'],
#    1047                   axis=rcParams['axes.grid.axis'])
#
# ~\Anaconda3\envs\MachineLearningV1\lib\site-packages\matplotlib\axes\_base.py in grid(self, b, which, axis, **kwargs)
#    2785             self.xaxis.grid(b, which=which, **kwargs)
#    2786         if axis in ['y', 'both']:
# -> 2787             self.yaxis.grid(b, which=which, **kwargs)
#    2788
#    2789     def ticklabel_format(self, *, axis='both', style='', scilimits=None,
#
# ~\Anaconda3\envs\MachineLearningV1\lib\site-packages\matplotlib\axis.py in grid(self, b, which, **kwargs)
#    1475                 self._gridOnMajor = b
#    1476             self.set_tick_params(which='major', gridOn=self._gridOnMajor,
# -> 1477                                  **gridkw)
#    1478         self.stale = True
#    1479
#
# ~\Anaconda3\envs\MachineLearningV1\lib\site-packages\matplotlib\axis.py in set_tick_params(self, which, reset, **kw)
#     886             # apply the new kwargs to the existing ticks
#     887             if which == 'major' or which == 'both':
# --> 888                 for tick in self.majorTicks:
#     889                     tick._apply_params(**kwtrans)
#     890             if which == 'minor' or which == 'both':
#
# ~\Anaconda3\envs\MachineLearningV1\lib\site-packages\matplotlib\axis.py in __get__(self, instance, cls)
#     668                 instance.majorTicks = []
#     669                 tick = instance._get_tick(major=True)
# --> 670                 instance.majorTicks.append(tick)
#     671                 return instance.majorTicks
#     672             else:
#
# ~\Anaconda3\envs\MachineLearningV1\lib\site-packages\matplotlib\axis.py in __get__(self, instance, cls)
#     667             if self._major:
#     668                 instance.majorTicks = []
# --> 669                 tick = instance._get_tick(major=True)
#     670                 instance.majorTicks.append(tick)
#     671                 return instance.majorTicks
#
# ~\Anaconda3\envs\MachineLearningV1\lib\site-packages\matplotlib\axis.py in _get_tick(self, major)
#    2220         else:
#    2221             tick_kw = self._minor_tick_kw
# -> 2222         return YTick(self.axes, 0, '', major=major, **tick_kw)
#    2223
#    2224     def _get_label(self):
#
# ~\Anaconda3\envs\MachineLearningV1\lib\site-packages\matplotlib\axis.py in __init__(self, axes, loc, label, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major, labelrotation, grid_color, grid_linestyle, grid_linewidth, grid_alpha, **kw)
#     157
#     158         self.tick1line = self._get_tick1line()
# --> 159         self.tick2line = self._get_tick2line()
#     160         self.gridline = self._get_gridline()
#     161         self.label1 = self._get_text1()
#
# ~\Anaconda3\envs\MachineLearningV1\lib\site-packages\matplotlib\axis.py in _get_tick2line(self)
#     595                           markersize=self._size,
#     596                           markeredgewidth=self._width,
# --> 597                           zorder=self._zorder)
#     598         l.set_transform(self.axes.get_yaxis_transform(which='tick2'))
#     599         self._set_artist_props(l)
#
# ~\Anaconda3\envs\MachineLearningV1\lib\site-packages\matplotlib\lines.py in __init__(self, xdata, ydata, linewidth, linestyle, color, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     380         self._color = None
#     381         self.set_color(color)
# --> 382         self._marker = MarkerStyle(marker, fillstyle)
#     383
#     384         self._markevery = None
#
# ~\Anaconda3\envs\MachineLearningV1\lib\site-packages\matplotlib\markers.py in __init__(self, marker, fillstyle)
#     241         self._marker_function = None
#     242         self.set_fillstyle(fillstyle)
# --> 243         self.set_marker(marker)
#     244
#     245     def _recache(self):
#
# ~\Anaconda3\envs\MachineLearningV1\lib\site-packages\matplotlib\markers.py in set_marker(self, marker)
#     314
#     315         self._marker = marker
# --> 316         self._recache()
#     317
#     318     def get_path(self):
#
# ~\Anaconda3\envs\MachineLearningV1\lib\site-packages\matplotlib\markers.py in _recache(self)
#     254         self._capstyle = 'butt'
#     255         self._filled = True
# --> 256         self._marker_function()
#     257
#     258     def __bool__(self):
#
# ~\Anaconda3\envs\MachineLearningV1\lib\site-packages\matplotlib\markers.py in _set_tickright(self)
#     753
#     754     def _set_tickright(self):
# --> 755         self._transform = Affine2D().scale(1.0, 1.0)
#     756         self._snap_threshold = 1.0
#     757         self._filled = False
#
# ~\Anaconda3\envs\MachineLearningV1\lib\site-packages\matplotlib\transforms.py in scale(self, sx, sy)
#    1989         scale_mtx = np.array(
#    1990             [[sx, 0.0, 0.0], [0.0, sy, 0.0], [0.0, 0.0, 1.0]], float)
# -> 1991         self._mtx = np.dot(scale_mtx, self._mtx)
#    1992         self.invalidate()
#    1993         return self
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
L
# Out:
# tensor(-0.8054, grad_fn=<SubBackward0>)

# %%
# %matplotlib notebook
# %matplotlib notebook

x_lin = torch.arange(-10, 10.0, 0.01).unsqueeze(-1)

Z = (1/(torch.sum(target(x_lin),dim=0)*0.01)).detach().cpu().numpy()
plt.plot(x_lin.detach().cpu().numpy(), Z*target(x_lin).detach().cpu().numpy())

Z = []
for i in range(5000):
    z = VAE()
    Z.append(z.detach().clone().cpu().squeeze().numpy())

plt.ylim(0, 5) 
plt.hist(np.stack(Z),bins=100,density=True);
plt.legend(['posterior', 'VAE'])
# Out:
# <img src="data:image/png;base64,..." width="1007">

# %%
VAE()
# Out:
# tensor([[ 1.0193, -0.9823,  0.8609]], grad_fn=<AddmmBackward>)
