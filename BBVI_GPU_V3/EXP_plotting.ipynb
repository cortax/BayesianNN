# %% [markdown]
# ## IMPORTS

# %%
from Inference import BBVI 
import torch
import matplotlib.pyplot as plt

# %% [markdown]
# ### Set the Device

# %%
device = torch.device('cuda:1' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# ### Load the data

# %%
data = torch.load('Data/foong_data.pt')
x_data = data[0].to(device)
y_data = data[1].to(device)
y_data = y_data.unsqueeze(-1)

# %% [markdown]
# ### Load Network XP1

# %%
nbLoops = 10

# %%
for i in [5, 20, 50, 100]:
    for j in [2,3]:
        for k in range(1, nbLoops+1):
            networkName = 'EXP1_' + str(j)+ 'Layers_' + str(i) + 'Neurons_(' + str(k) +')'
            Net = torch.load('Saved/EXP1/' + networkName)
            BBVI.plot_BBVI(model=Net, data=data, device=device, savePath='Results/EXP1/', networkName=networkName, saveName='PD');
# Out:
# /home/maala89/BOMBARDIER/BBVI/BBVI_GPU_V3/Inference/BBVI.py:267: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots()

# %% [markdown]
# ### Load Network XP2

# %%
nbLoops = 10

# %%
for i in [5, 20, 50, 100]:
    for j in [2,3]:
        for k in range(1, nbLoops+1):
            networkName = 'EXP2_' + str(j)+ 'Layers_' + str(i) + 'Neurons_(' + str(k) +')'
            Net = torch.load('Saved/EXP2/' + networkName)
            BBVI.plot_BBVI(model=Net, data=data,  v    device=device, savePath='Results/EXP2/', networkName=networkName, saveName='PD');

# %% [markdown]
# ### Load Network XP3

# %%
nbLoops = 10

# %%
for i in [5, 20, 50, 100]:
    for j in [2,3]:
        for k in range(1, nbLoops+1):
            networkName = 'EXP3_' + str(j)+ 'Layers_' + str(i) + 'Neurons_(' + str(k) +')'
            Net = torch.load('Saved/EXP3/' + networkName)
            BBVI.plot_BBVI(model=Net, data=data, device=device, savePath='Results/EXP3/', networkName=networkName, saveName='PD');
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-4bb92930873a> in <module>
#       4             networkName = 'EXP3_' + str(j)+ 'Layers_' + str(i) + 'Neurons_(' + str(k) +')'
#       5             Net = torch.load('Saved/EXP3/' + networkName)
# ----> 6             BBVI.plot_BBVI(model=Net, data=data, device=device, savePath='Results/EXP3/', networkName=networkName, saveName='PD');
#
# ~/BOMBARDIER/BBVI/BBVI_GPU_V3/Inference/BBVI.py in plot_BBVI(model, data, device, savePath, xpName, networkName, saveName)
#     275     for _ in range(1500):
#     276
# --> 277         model.sample_parameters()
#     278
#     279         y_test = model.forward(x_test)
#
# ~/BOMBARDIER/BBVI/BBVI_GPU_V3/Inference/BBVI.py in sample_parameters(self, M)
#     167         layered_w_samples = []
#     168         layered_bias_samples = []
# ...
