# %%
mixture_size = 2:50
layer_size = [10,25,50,100]
nb_layer = [2,3,4]
nb_trial = 30

# %%
A = [];

# %%
with open('job_parameters_array_ext', 'w+') as f: 
    for W in layer_size:
        for L in nb_layer:
            for j in range(nb_trial):
                #A.append(str(L)+';'+str(W)+';'+str(j+30))
                    f.write(str(L)+';'+str(W)+';'+str(j)+'\n')

# %%
A
# Out:
# ['2;10;30',
#  '2;10;31',
#  '2;10;32',
#  '2;10;33',
#  '2;10;34',
#  '2;10;35',
#  '2;10;36',
#  '2;10;37',
#  '2;10;38',
#  '2;10;39',
#  '2;10;40',
#  '2;10;41',
#  '2;10;42',
#  '2;10;43',
#  '2;10;44',
#  '2;10;45',
#  '2;10;46',
#  '2;10;47',
#  '2;10;48',
#  '2;10;49',
#  '2;10;50',
#  '2;10;51',
#  '2;10;52',
#  '2;10;53',
#  '2;10;54',
#  '2;10;55',
#  '2;10;56',
#  '2;10;57',
#  '2;10;58',
#  '2;10;59',
#  '2;10;60',
#  '2;10;61',
#  '2;10;62',
#  '2;10;63',
#  '2;10;64',
#  '2;10;65',
#  '2;10;66',
#  '2;10;67',
#  '2;10;68',
#  '2;10;69',
#  '2;10;70',
#  '2;10;71',
#  '2;10;72',
#  '2;10;73',
#  '2;10;74',
#  '2;10;75',
#  '2;10;76',
#  '2;10;77',
#  '2;10;78',
#  '2;10;79',
#  '2;10;80',
#  '2;10;81',
#  '2;10;82',
#  '2;10;83',
#  '2;10;84',
#  '2;10;85',
#  '2;10;86',
#  '2;10;87',
#  '2;10;88',
#  '2;10;89',
#  '2;10;90',
#  '2;10;91',
#  '2;10;92',
#  '2;10;93',
#  '2;10;94',
#  '2;10;95',
#  '2;10;96',
#  '2;10;97',
#  '2;10;98',
#  '2;10;99',
#  '2;10;100',
# ...
